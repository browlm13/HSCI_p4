# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#import collected data
time = loadtxt('time.txt')
Temp = loadtxt('Temp.txt')

C2mm = loadtxt('C2mm.txt')
C4mm = loadtxt('C4mm.txt')

C2mm_800K = loadtxt('C2mm_800K.txt')
C2mm_900K = loadtxt('C2mm_900K.txt')
C2mm_1000K = loadtxt('C2mm_1000K.txt')
C2mm_1100K = loadtxt('C2mm_1100K.txt')
C2mm_1200K = loadtxt('C2mm_1200K.txt')

C4mm_800K = loadtxt('C4mm_800K.txt')
C4mm_900K = loadtxt('C4mm_900K.txt')
C4mm_1000K = loadtxt('C4mm_1000K.txt')
C4mm_1100K = loadtxt('C4mm_1100K.txt')
C4mm_1200K = loadtxt('C4mm_1200K.txt')

# %%
figure()
imshow(C2mm)
colorbar(orientation='horizontal')
colorbar()

# %%
figure()
imshow(C4mm)
title('carbon concentrations at a 4 mm depth')
ylabel('Temperature K')
xlabel('Time')
colorbar(orientation='horizontal')
colorbar()

# %%
plot(time,C2mm_800K, time, C2mm_900K, time, C2mm_1000K, time, C2mm_1100K, time, C2mm_1200K)
title('carbon concentrations at a 2 mm depth')
ylabel('Carbon Concentration')
xlabel('Time')
legend(('$800K$', '$900K$', '$1000K$', '$1100K$', '$1200K$'))

#adjusting xticks
xticks( (1*3600, 6*3600, 12*3600, 24*3600, 36*3600, 48*3600),
('1 hr', '6 hr', '12 hr', '24 hr', '36 hr', '48 hr') )
# Out:
# ([<matplotlib.axis.XTick at 0x10ac3c828>,
#   <matplotlib.axis.XTick at 0x1042a27b8>,
#   <matplotlib.axis.XTick at 0x10ac2eac8>,
#   <matplotlib.axis.XTick at 0x10ffad588>,
#   <matplotlib.axis.XTick at 0x10ffadf98>,
#   <matplotlib.axis.XTick at 0x10ffb09e8>],
#  <a list of 6 Text xticklabel objects>)

# %%
#import numpy as np
plot(time,C4mm_800K, time, C4mm_900K, time, C4mm_1000K, time, C4mm_1100K, time, C4mm_1200K)
title('carbon concentrations at a 4 mm depth')
ylabel('Carbon Concentration')
xlabel('Time')
legend(('$800K$', '$900K$', '$1000K$', '$1100K$', '$1200K$'))

#adjusting xticks
xticks( (1*3600, 6*3600, 12*3600, 24*3600, 36*3600, 48*3600),
('1 hr', '6 hr', '12 hr', '24 hr', '36 hr', '48 hr') )
# Out:
# ([<matplotlib.axis.XTick at 0x10ab41630>,
#   <matplotlib.axis.XTick at 0x10abe8eb8>,
#   <matplotlib.axis.XTick at 0x10abe2080>,
#   <matplotlib.axis.XTick at 0x10d4b8f60>,
#   <matplotlib.axis.XTick at 0x10d4b99b0>,
#   <matplotlib.axis.XTick at 0x10d4bc400>],
#  <a list of 6 Text xticklabel objects>)
